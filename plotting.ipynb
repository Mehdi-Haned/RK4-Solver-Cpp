# %%
## Example of the code versus the Scipy Solver

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# parametreters of the system.
om = 2*np.pi
om_0 = 1.5*om
b = om_0 * 0.25
gamma = 1.073

def f(L, t, om, om_0, b, g):
    x1, x2 = L
    dxdt = [x2, -2*b*x2 - (om_0**2)*np.sin(x1) + g*(om_0**2)*np.cos(om*t)]
    return dxdt

ics = [0, 1] #initial conditions for x1 and x2 respectively

data = np.loadtxt("Rk4_sol.dat")

t = data[:,0]

sol = odeint(f, ics, t, args=(om, om_0, b, gamma)) #Same system is solved using the odeint funtion from scipy.integrate

fig, axs = plt.subplots(2)

axs[0].plot(t, sol[:,0])  #x1 with scipy
axs[0].plot(t, data[:,1]) #x1 with my code

axs[1].plot(t, sol[:,1])  #x2 with scipy
axs[1].plot(t, data[:,2]) #x2 with my code

# %%
data = np.loadtxt("Rk4_sol.dat")

data
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [1.00000000e-02, 1.44400693e-02, 1.87867044e+00],
#        [2.00000000e-02, 3.73718015e-02, 2.69692596e+00],
#        ...,
#        [9.98000000e+00, 4.06422664e+00, 1.19698903e+01],
#        [9.99000000e+00, 4.18940373e+00, 1.30680701e+01],
#        [1.00000000e+01, 4.32561984e+00, 1.41756105e+01]])
